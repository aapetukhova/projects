# %%
списки из интервалов в слое


что мы можем с этим делать:
    частотности слов каждого говорящего - как создавать корпус?
    нам нужно уметь смотреть

# %%
from praatio import tgio
from functools import wraps
import re
import os


# class ParseTextGrid:
#     def __init__(self, filename):
#         self.filename = filename

#     def file_open(self):
#         return tgio.openTextgrid(self.filename)

#     def morph(self):
#         tg = self.file_open()
#         morph_tier = tg.tierDict["говорящий1_ЭДЕ"]
#         morph_list = [list(word) for word in morph_tier.entryList]
#         return morph_list

#     def gloss(self):
#         tg = self.file_open()
#         gloss_tier = tg.tierDict["говорящий1_рус"]
#         gloss_list = [list(word) for word in gloss_tier.entryList]
#         return gloss_list

#     def translation(self):
#         tg = self.file_open()
#         translation_tier = tg.tierDict["говорящий1_якт"]
#         translation_list = [list(word) for word in translation_tier.entryList]
#         return translation_list

#     def comment(self):
#         tg = self.file_open()
#         comment_tier = tg.tierDict["говорящий1_перевод"]
#         comment_list = [list(word) for word in comment_tier.entryList]
#         return comment_list

# class MakeGlossLine(ParseTextGrid):
#     def sent_start_end(self, morph):
#         idx_list = []
#         for el in self.translation():
#             start = el[0]
#             end = el[1]
#             for i in range(len(morph)):
#                 if morph[i][0] == start:
#                     for j in range(len(morph)):
#                         if i + j < len(morph) and morph[i + j][1] == end:
#                             idx_list.append((i, i + j))
#                         j += 1
#         return idx_list
    
# a = MakeGlossLine('game_1-885s.TextGrid')
# print(a)

# %%
from os.path import join
from praatio import tgio
import collections

input_filename = 'game_1-885s.TextGrid'
tg = tgio.openTextgrid(input_filename)

# print(tg.tierNameList)

# rus words
rus = []
for i in range(1, 17, 5):
    a = tg.tierDict[tg.tierNameList[i]]
    r_list = [entry[2] for entry in a.entryList]
    rus.extend(r_list)
# print(rus)
r_dict = collections.Counter(rus)
print(r_dict)

# ykt words
ykt = []
for i in range(2, 18, 5):
    b = tg.tierDict[tg.tierNameList[i]]
    y_list = [entry[2] for entry in b.entryList]
    ykt.extend(y_list)
y_dict = collections.Counter(ykkt)
print(y_dict)

# synt
synt = []
for i in range(4, 20, 5):
    c = tg.tierDict[tg.tierNameList[i]]
    s_list = [entry[2] for entry in c.entryList]
    synt.extend(s_list)
s_dict = collections.Counter(synt)
print(s_dict)

# r_list = [entry[2] for entry in rus.entryList]
# print(len(r_list))
# print(r_list)
# y_list = [entry[2] for entry in ykt.entryList]
# s_list = [entry[2] for entry in synt.entryList]
    
# first_tier = tg.tierDict[tg.tierNameList[0]]
# rus = tg.tierDict[tg.tierNameList[1]]
# ykt = tg.tierDict[tg.tierNameList[2]]
# inter = tg.tierDict[tg.tierNameList[21]]




# print(first_tier)

# label_list = [entry[1] for entry in inter.entryList]
# print(label_list)

# print(inter.entryList[0])
# a = [(10.905109092472985, 12.30935693029235)]
# ptl = inter.getValuesAtPoints(a)
# print(ptl)
# Out:
# Counter({'а': 22, 'два': 19, 'не': 19, 'ты': 16, 'да': 15, 'это': 15, 'я': 14, 'у': 11, 'раз': 10, 'нет': 10, 'сто': 10, 'ну': 10, 'тысяч': 10, 'четыре': 9, 'три': 9, 'так': 8, 'все': 8, 'пять': 8, 'ага': 8, 'семь': 7, 'десять': 7, 'за': 6, 'берешь': 6, 'шесть': 6, 'что': 6, 'еще': 5, 'кто': 5, 'сюда': 5, 'короче': 5, 'с': 5, 'девять': 5, 'вот': 4, 'в': 4, 'деньги': 4, 'тут': 4, 'на': 4, 'теперь': 4, 'если': 4, 'тебя': 4, 'то': 4, 'меня': 4, 'одиннадцать': 4, 'ка': 4, 'миллиона': 4, 'вообще': 4, 'бери': 4, 'уже': 3, 'колдуй': 3, 'беру': 3, 'там': 3, 'бы': 3, 'сколько': 3, 'шестьсот': 3, 'просто': 3, 'давай': 3, 'ааа': 3, 'мне': 3, 'эээ': 3, 'же': 3, 'почему': 3, 'и': 3, 'потом': 2, 'карточку': 2, 'где': 2, 'получаешь': 2, 'тюрьму': 2, 'идешь': 2, 'миллион': 2, 'тебе': 2, 'тина': 2, 'одинаковые': 2, 'тоже': 2, 'типа': 2, 'заплати': 2, 'пока': 2, 'начинается': 2, 'этого': 2, 'можно': 2, 'равно': 2, 'купил': 2, 'больше': 2, 'меньше': 2, 'всего': 2, 'денег': 2, 'него': 2, 'сейчас': 2, 'в
# ...

# %%
from os.path import join
from praatio import tgio
import collections

input_filename = 'game_1-885s.TextGrid'
tg = tgio.openTextgrid(input_filename)

# print(tg.tierNameList)

# rus words
rus = []
for i in range(1, 17, 5):
    a = tg.tierDict[tg.tierNameList[i]]
    r_list = [entry[2] for entry in a.entryList]
    rus.extend(r_list)
# print(rus)
r_dict = collections.Counter(rus)

print(r_dict)

# ykt words
ykt = []
for i in range(2, 18, 5):
    b = tg.tierDict[tg.tierNameList[i]]
    y_list = [entry[2] for entry in b.entryList]
    ykt.extend(y_list)
y_dict = collections.Counter(ykt)
print(y_dict)

# synt
synt = []
for i in range(4, 20, 5):
    c = tg.tierDict[tg.tierNameList[i]]
    s_list = [entry[2] for entry in c.entryList]
    synt.extend(s_list)
s_dict = collections.Counter(synt)
print(s_dict)
# Out:
# Counter({'а': 22, 'два': 19, 'не': 19, 'ты': 16, 'да': 15, 'это': 15, 'я': 14, 'у': 11, 'раз': 10, 'нет': 10, 'сто': 10, 'ну': 10, 'тысяч': 10, 'четыре': 9, 'три': 9, 'так': 8, 'все': 8, 'пять': 8, 'ага': 8, 'семь': 7, 'десять': 7, 'за': 6, 'берешь': 6, 'шесть': 6, 'что': 6, 'еще': 5, 'кто': 5, 'сюда': 5, 'короче': 5, 'с': 5, 'девять': 5, 'вот': 4, 'в': 4, 'деньги': 4, 'тут': 4, 'на': 4, 'теперь': 4, 'если': 4, 'тебя': 4, 'то': 4, 'меня': 4, 'одиннадцать': 4, 'ка': 4, 'миллиона': 4, 'вообще': 4, 'бери': 4, 'уже': 3, 'колдуй': 3, 'беру': 3, 'там': 3, 'бы': 3, 'сколько': 3, 'шестьсот': 3, 'просто': 3, 'давай': 3, 'ааа': 3, 'мне': 3, 'эээ': 3, 'же': 3, 'почему': 3, 'и': 3, 'потом': 2, 'карточку': 2, 'где': 2, 'получаешь': 2, 'тюрьму': 2, 'идешь': 2, 'миллион': 2, 'тебе': 2, 'тина': 2, 'одинаковые': 2, 'тоже': 2, 'типа': 2, 'заплати': 2, 'пока': 2, 'начинается': 2, 'этого': 2, 'можно': 2, 'равно': 2, 'купил': 2, 'больше': 2, 'меньше': 2, 'всего': 2, 'денег': 2, 'него': 2, 'сейчас': 2, 'в
# ...

# %%
from os.path import join
from praatio import tgio
import collections

input_filename = 'game_1-885s.TextGrid'
tg = tgio.openTextgrid(input_filename)


def count_list(input_filename, x, y, filename): #x - from, y - to
#     input_filename = 'game_1-885s.TextGrid'
    tg = tgio.openTextgrid(input_filename)
    main_list = []
    for i in range(x, y, 5):
        a = tg.tierDict[tg.tierNameList[i]]
        word_list = [entry[2] for entry in a.entryList]
        main_list.extend(word_list)
    c_dict = collections.Counter(main_list)

#     return c_dict
    with open(filename, 'w', encoding='utf-8') as f:
        for key in sorted(c_dict, key=c_dict.get, reverse=True):
#             print(key, c_dict[key])
#         for key, value in c_dict.items():
# + regex search for endings
            f.write(key)
            f.write(' ')
            f.write(str(c_dict[key]))
            f.write('\n')

# count_list('game_1-885s.TextGrid', 1, 17, 'rus_words.txt')
count_list('game_1-885s.TextGrid', 2, 18, 'ykt_words.txt')
# count_list('game_1-885s.TextGrid', 4, 20, 'synt_count.txt')

# %%
from praatio import tgio

def topWordsS(lan_num):
    tg = tgio.openTextgrid('all_2.TextGrid')
    lan = tg.tierDict[tg.tierNameList[lan_num]]
#     synt = tg.tierDict[tg.tierNameList[lan_num]]
    cs = tg.tierDict[tg.tierNameList[21]]
#     cs_list = [entry for entry in cs.entryList]
    rus_list = []
    for point, label in cs.entryList:
        if label == 'r':
            rus_list.append(point)           
    
    words = []

    for start, end, label in lan.entryList:        
        if start in rus_list:
            words.append(label)
    counter = collections.Counter(words)
#     print(counter)
    return counter

# %%
def bigCounterS(num): 
    a = topWordsS(num) 
    for i in range(num + 5, num + 15, 5): 
        a.update(topWords(i))
#     return a
    print(a)
